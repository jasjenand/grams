# %% [markdown]
# import necessary libraries & assign csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
hot100 = pd.read_csv("HotStuff2.csv")
pfork = pd.read_csv("ps4k.csv")
goat = pd.read_csv("goats.csv").set_index("Number")
winners = pd.read_csv("gramcys.csv").drop(columns="awardType").sort_values("annualGrammy").reset_index(drop=True)

# %%
#FUNCTIONS
def albumGrammyInfo(album):
    artist = winners.iloc[index]["name"]
    year = winners.iloc[index]["year"]
    cat = winners.iloc[index]["category"]
    print("In %d, %s won %s for %s." % (year, artist, cat, album))

# %%
def songGrammyInfo(song):
    artist = winners.iloc[index]["name"]
    year = winners.iloc[index]["year"]
    cat = winners.iloc[index]["category"]
    print("In %d, %s won %s for %s." % (year, artist, cat, song))

# %%
def findGOATalbum(album):
    if goat["Album"].str.contains(album).any():
        print("The Rolling Stones considers this album one of the GOATs.")
        display(goat.loc[goat["Album"] == album])
    else:
        pass

# %%
def findOthers(year):
    if goat["Year"].isin([year]).any():
        goatNum = len(goat.loc[goat["Year"] == year])
        if goatNum > 1:
            print("Actually, " + str(goatNum) + " GOAT albums came out that year.")
            display(goat.loc[goat["Year"] == year])
    else:
        pass

# %%
def findGOATartist(artist):
    if goat["Artist"].str.contains(artist).any():
        albumCount = len(goat.loc[goat["Artist"] == artist])
        print("They do have " + str(albumCount) + " GOAT album(s) though.")
        display(goat.loc[goat["Artist"] == artist])

# %%
def findP4Krating(album):
    if pfork["album"].str.contains(album).any():
        rating = pfork.loc[pfork["album"] == album]
        score = rating.iloc[0]["score"]
        artistName = rating.iloc[0]["artist"]
        print("Pitchfork rated %s by %s: %g out of 10." % (album, artistName, score))

# %%
#BILLBOARD HOT 100 SECTION
#order hot100.csv file by week and chart position
hot100["WeekID"]=pd.to_datetime(hot100["WeekID"])
hot100.sort_values(["WeekID", "Week Position"], inplace=True, ascending=True)
hot100.set_index("WeekID")
# Out:
#             Week Position                                               Song  \
# WeekID
# 1958-08-02              1                                   Poor Little Fool
# 1958-08-02              2                                           Patricia
# 1958-08-02              3                                      Splish Splash
# 1958-08-02              4                                  Hard Headed Woman
# 1958-08-02              5                                               When
# 1958-08-02              6                                      Rebel-'rouser
# 1958-08-02              7                                         Yakety Yak
# 1958-08-02              8                                       My True Love
# 1958-08-02              9                           Willie And The Hand Jive
# 1958-08-02             10                                              Fever
# 1958-08-02             11                                       Ginger Bread
# 1958-08-02             12                                       Just A Dream
# 1958-08-02             13  Left Right Out Of Your Heart (Hi Lee Hi Lo Hi ...
# 1958-08-02             14                                If Dreams Came True
# 1958-08-02             15                             For Your Precious Love
# 1958-08-02             16                                   One Summer Night
# 1958-08-02             17                                      Endless Sleep
# 1958-08-02             18                                        Little Star
# 1958-08-02             19                            Everybody Loves A Lover
# 1958-08-02             20                               Do You Want To Dance
# 1958-08-02             21                       Guess Things Happen That Way
# 1958-08-02             22                                    A Certain Smile
# 1958-08-02             23                                     Western Movies
# 1958-08-02             24                            The Purple People Eater
# 1958-08-02             25                               What Am I Living For
# 1958-08-02             26                                      Born Too Late
# 1958-08-02             27                                      Think It Over
# 1958-08-02             28                                           Secretly
# 1958-08-02             29                                   Enchanted Island
# 1958-08-02             30                                         Angel Baby
# ...                   ...                                                ...
# 2018-12-29             71                                      Girl Like You
# 2018-12-29             72                                          Good Girl
# 2018-12-29             73                                         No Stylist
# 2018-12-29             74                                          Testimony
# 2018-12-29             75                                                You
# 2018-12-29             76                                               KIKA
# 2018-12-29             77                              When The Party's Over
# 2018-12-29             78                                          Last Shot
# 2018-12-29             79                                 whoa (mind in awe)
# 2018-12-29             80                                  Ella Quiere Beber
# 2018-12-29             81                                    Beautiful Crazy
# 2018-12-29             82                                         Fine China
# 2018-12-29             83                                      Lost In Japan
# 2018-12-29             84                                         This Is It
# 2018-12-29             85                        Smile (Living My Best Life)
# 2018-12-29             86                                      Close Friends
# 2018-12-29             87                                   Sweet But Psycho
# 2018-12-29             88                                             Gnarly
# 2018-12-29             89                                             Lovely
# 2018-12-29             90                                 The Christmas Song
# 2018-12-29             91                                            Envy Me
# 2018-12-29             92                                           Yosemite
# 2018-12-29             93                                        Electricity
# 2018-12-29             94                                          Good Form
# 2018-12-29             95                                        Millionaire
# 2018-12-29             96                                    Look Back At It
# 2018-12-29             97                                               24/7
# 2018-12-29             98                                       Uptown Vibes
# 2018-12-29             99                                           Nuketown
# 2018-12-29            100                                               MAMA
#
#                                                 Performer  Instance  \
# WeekID
# 1958-08-02                                   Ricky Nelson         1
# 1958-08-02                  Perez Prado And His Orchestra         1
# 1958-08-02                                    Bobby Darin         1
# 1958-08-02             Elvis Presley With The Jordanaires         1
# 1958-08-02                                    Kalin Twins         1
# 1958-08-02    Duane Eddy His Twangy Guitar And The Rebels         1
# 1958-08-02                                   The Coasters         1
# 1958-08-02                                     Jack Scott         1
# 1958-08-02                           The Johnny Otis Show         1
# 1958-08-02                                      Peggy Lee         1
# 1958-08-02                                 Frankie Avalon         1
# 1958-08-02                  Jimmy Clanton And His Rockets         1
# 1958-08-02                                     Patti Page         1
# 1958-08-02                                      Pat Boone         1
# 1958-08-02               Jerry Butler and The Impressions         1
# 1958-08-02                                   The Danleers         1
# 1958-08-02                                  Jody Reynolds         1
# 1958-08-02                                   The Elegants         1
# 1958-08-02                                      Doris Day         1
# 1958-08-02                                  Bobby Freeman         1
# 1958-08-02              Johnny Cash And The Tennessee Two         1
# 1958-08-02                                  Johnny Mathis         1
# 1958-08-02                                   The Olympics         1
# 1958-08-02                                    Sheb Wooley         1
# 1958-08-02                                   Chuck Willis         1
# 1958-08-02                                     Poni-Tails         1
# 1958-08-02                                   The Crickets         1
# 1958-08-02                                 Jimmie Rodgers         1
# 1958-08-02                                  The Four Lads         1
# 1958-08-02                                    Dean Martin         1
# ...                                                   ...       ...
# 2018-12-29                                   Jason Aldean         2
# 2018-12-29                                   Dustin Lynch         1
# 2018-12-29                 French Montana Featuring Drake         1
# 2018-12-29                                    Kodak Black         1
# 2018-12-29                                       Jacquees         1
# 2018-12-29                   6ix9ine Featuring Tory Lanez         1
# 2018-12-29                                  Billie Eilish         1
# 2018-12-29                                      Kip Moore         2
# 2018-12-29                                   XXXTENTACION         1
# 2018-12-29                        Anuel AA & Romeo Santos         1
# 2018-12-29                                     Luke Combs         3
# 2018-12-29                            Future & Juice WRLD         1
# 2018-12-29                            Shawn Mendes X Zedd         2
# 2018-12-29                                Scotty McCreery         1
# 2018-12-29  Lil' Duval Featuring Snoop Dogg & Ball Greezy         1
# 2018-12-29                                       Lil Baby         1
# 2018-12-29                                        Ava Max         1
# 2018-12-29                 Kodak Black Featuring Lil Pump         1
# 2018-12-29                         Billie Eilish & Khalid         3
# 2018-12-29                                  Lauren Daigle         1
# 2018-12-29                                         Calboy         1
# 2018-12-29                                   Travis Scott         2
# 2018-12-29                           Silk City x Dua Lipa         4
# 2018-12-29                Nicki Minaj Featuring Lil Wayne         1
# 2018-12-29                                Chris Stapleton         2
# 2018-12-29                         A Boogie Wit da Hoodie         1
# 2018-12-29                   Meek Mill Featuring Ella Mai         1
# 2018-12-29        Meek Mill Featuring Fabolous & Anuel AA         1
# 2018-12-29    Ski Mask The Slump God Featuring Juice WRLD         1
# 2018-12-29     6ix9ine Featuring Nicki Minaj & Kanye West         1
#
#             Previous Week Position  Peak Position  Weeks on Chart
# WeekID
# 1958-08-02                     NaN              1               1
# 1958-08-02                     NaN              2               1
# 1958-08-02                     NaN              3               1
# 1958-08-02                     NaN              4               1
# 1958-08-02                     NaN              5               1
# 1958-08-02                     NaN              6               1
# 1958-08-02                     NaN              7               1
# 1958-08-02                     NaN              8               1
# 1958-08-02                     NaN              9               1
# 1958-08-02                     NaN             10               1
# 1958-08-02                     NaN             11               1
# 1958-08-02                     NaN             12               1
# 1958-08-02                     NaN             13               1
# 1958-08-02                     NaN             14               1
# 1958-08-02                     NaN             15               1
# 1958-08-02                     NaN             16               1
# 1958-08-02                     NaN             17               1
# 1958-08-02                     NaN             18               1
# 1958-08-02                     NaN             19               1
# 1958-08-02                     NaN             20               1
# 1958-08-02                     NaN             21               1
# 1958-08-02                     NaN             22               1
# 1958-08-02                     NaN             23               1
# 1958-08-02                     NaN             24               1
# 1958-08-02                     NaN             25               1
# 1958-08-02                     NaN             26               1
# 1958-08-02                     NaN             27               1
# 1958-08-02                     NaN             28               1
# 1958-08-02                     NaN             29               1
# 1958-08-02                     NaN             30               1
# ...                            ...            ...             ...
# 2018-12-29                    77.0             71               4
# 2018-12-29                    81.0             72               6
# 2018-12-29                    85.0             47              13
# 2018-12-29                     NaN             74               1
# 2018-12-29                    83.0             75               4
# 2018-12-29                    60.0             44               4
# 2018-12-29                    69.0             52               9
# 2018-12-29                    87.0             78               5
# 2018-12-29                    37.0             37               2
# 2018-12-29                    93.0             79               7
# 2018-12-29                    97.0             81               6
# 2018-12-29                    89.0             26               9
# 2018-12-29                    56.0             48              13
# 2018-12-29                    96.0             84               2
# 2018-12-29                    88.0             56              17
# 2018-12-29                    90.0             28              11
# 2018-12-29                     NaN             87               1
# 2018-12-29                     NaN             88               1
# 2018-12-29                     NaN             89               8
# 2018-12-29                     NaN             90               1
# 2018-12-29                     NaN             91               1
# 2018-12-29                   100.0             92              10
# 2018-12-29                     NaN             93               6
# 2018-12-29                    94.0             60               3
# 2018-12-29                     NaN             95               3
# 2018-12-29                    95.0             95               2
# 2018-12-29                    86.0             54               3
# 2018-12-29                    79.0             39               3
# 2018-12-29                    98.0             63               3
# 2018-12-29                    75.0             43               4
#
# [315295 rows x 7 columns]

# %%
#GRAMMY SECTION
while True:
    interest = input("Are you interested in artists, albums, or songs? ")
    if interest.lower() not in ("artists", "albums", "songs"):
        print("try again sweetie.")
    else:
        break
    
if interest.lower() == "artists":
    artistQuery = input("Pick an artist: ")
    if winners["name"].str.contains(artistQuery).any():
        gramCount = len(winners.loc[winners["name"] == artistQuery])
        print("Total number of Grammy awards: " + str(gramCount))
        display(winners.loc[winners["name"] == artistQuery])
    else:
        print("They don't have any Grammy Awards.")
        findGOATartist(artistQuery)
           
elif interest.lower() == "albums":
    albumQuery = input("Pick an album: ")
    findP4Krating(albumQuery) #DANGER WILL ROBINSON
    if winners["awardFor"].str.contains(albumQuery).any():
        gramCount = len(winners.loc[winners["awardFor"] == albumQuery])
        print("Total number of Grammy awards: " + str(gramCount))
        display(winners.loc[winners["awardFor"] == albumQuery])
    else:
        print("This album has no Grammy Awards.")
        findGOATalbum(albumQuery)    
    
elif interest.lower() == "songs":
    songQuery = input("Pick a song: ")
    if winners["awardFor"].str.contains(songQuery).any():
        gramCount = len(winners.loc[winners["awardFor"] == songQuery])
        print("Total number of Grammy awards: " + str(gramCount))
        display(winners.loc[winners["awardFor"] == songQuery])
    else:
        print("This song has no Grammy Awards.")
        
        
#don't pick a Best New Artist category
index = int(input("Type the index number of a category you're interested in: "))
winners.iloc[index]

if winners.iloc[index].str.contains("Album").any():
    albumQuery = winners.iloc[index]["awardFor"]
    albumYear = winners.iloc[index]["year"] - 1
    albumGrammyInfo(albumQuery)
    findP4Krating(albumQuery)
    findGOATalbum(albumQuery)
    findOthers(albumYear)
    
else:
    songQuery = winners.iloc[index]["awardFor"]
    songGrammyInfo(songQuery)
# Out:
# Are you interested in artists, albums, or songs? songs
# Pick a song: Break Free
# This song has no Grammy Awards.
# Type the index number of a category you're interested in: 0
# In 1959, Nel Blu Dipinto Di Blu (Volare) won Record Of The Year for Nel Blu Dipinto Di Blu (Volare).

# %%
#PITCHFORK REVIEWS SECTION
pfork["date"] = pd.to_datetime(pfork["date"])

#search by album
album = input("Find an album: ")
if pfork["album"].str.contains(album).any():
    rating = pfork.loc[pfork["album"] == album]
    if len(rating) > 1:
        display(rating)
    else:
        score = rating.iloc[0]["score"]
        artistName = rating.iloc[0]["artist"]
        print("Pitchfork rated this album by %s: %g out of 10." % (artistName, score))
else: print("Pitchfork hasn't reviewed this album.")
# Out:
# Find an album: Bad
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-05a8c0f4d766> in <module>
#       9         display(rating)
#      10     else:
# ---> 11         score = rating.iloc[0]["score"]
#      12         artistName = rating.iloc[0]["artist"]
#      13         print("Pitchfork rated this album by %s: %g out of 10." % (artistName, score))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
#search by artist
artist = input("Find an artist: ")
rating = pfork.loc[pfork["artist"] == artist].reset_index(drop=True)
display(rating)
# Out:
# Find an artist: Billy Joel
# Empty DataFrame
# Columns: [album, artist, date, genre, score]
# Index: []

# %%
#GREATEST ALBUMS SECTION
#search by album
def findGOATalbum(album):
    if goat["Album"].str.contains(album).any():
        print("Heck yeah!")
        return goat.loc[goat["Album"] == album]
    else:
        print("Sorry, it's not...yet.")

albumQuery = input("Is this album a GOAT? ")        
findGOATalbum(albumQuery)
# Out:
# Is this album a GOAT? Thriller
# Heck yeah!
#         Year     Album           Artist             Genre
# Number
# 20      1982  Thriller  Michael Jackson  Funk / Soul, Pop

# %%
#search by artist
def findGOATartist(artist):
    if goat["Artist"].str.contains(artist).any():
        albumCount = len(goat.loc[goat["Artist"] == artist])
        print("Heck yeah! They have " + str(albumCount) + " GOAT albums.")
        return goat.loc[goat["Artist"] == artist]
    else:
        print("Sorry, they don't...yet.")

artistQuery = input("Does this artist have GOATs? ")
findGOATartist(artistQuery)
# Out:
# Does this artist have GOATs? Billy Joel
# Heck yeah! They have 2 GOAT albums.
#         Year         Album      Artist            Genre
# Number
# 70      1977  The Stranger  Billy Joel             Rock
# 354     1978   52nd Street  Billy Joel  Jazz, Rock, Pop

# %%
#search by year
def findGOATyear(year):
    if goat["Year"].isin([year]).any():
        goatNum = len(goat.loc[goat["Year"] == year])
        print(str(goatNum) + " GOAT albums came out that year.")
        return goat.loc[goat["Year"] == year]
    else:
        print("That is all.")
        print(type(goat["Year"]))

yearQuery = int(input("Any GOATs this year? "))
findGOATyear(yearQuery)
# Out:
# Any GOATs this year? 1980
# 9 GOAT albums came out that year.
#         Year            Album             Artist             Genre
# Number
# 77      1980    Back in Black              AC/DC              Rock
# 129     1980  Remain in Light      Talking Heads  Electronic, Rock
# 155     1980       Pretenders         Pretenders              Rock
# 157     1980           Closer       Joy Division              Rock
# 206     1980       Dirty Mind             Prince       Funk / Soul
# 253     1980        The River  Bruce Springsteen              Rock
# 287     1980      Los Angeles                  X              Rock
# 407     1980      Sandinista!          The Clash      Rock, Reggae
# 417     1980              Boy                 U2              Rock

# %%
#Graph of GOATS
print("Topics: Year, Artist, Genre")
topic = input("Please enter one of the topics above: ")
if topic == "Year":
    fig = plt.figure()
    groups =goat.Year.value_counts().head(10)
    labels = groups.index
    colors = ['#00008b','#1c1cf0','#5740ec','#7750cc','#9760ac','#b7708c','#d7806c','#dd9484','#e3a89c','#f0d1cc']
    plt.pie(groups, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
    plt.show()
if topic == "Artist":
    fig = plt.figure()
    groups =goat.Artist.value_counts().head(10)
    labels = groups.index
    colors = ['#faffcd','#f0c09a','#f0a173','#ec6358','#d33b57','#9e2d53','#591e54','#481d79','#331455','#141d55']
    plt.pie(groups, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
    plt.show()
if topic == "Genre":
    fig = plt.figure()
    groups =goat.Genre.value_counts().head(10)
    labels = groups.index
    colors = ['#693e8d','#7054b6','#726ac9','#6d81c7','#6f91cc','#698be7','#8993e0','#a99bd9','#c9a3d2','#d9abcb']
    plt.pie(groups, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
    plt.show()
# Out:
# Topics: Year, Artist, Genre
